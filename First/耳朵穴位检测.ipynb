# %% [markdown]
# # 耳朵目标检测-训练

# %% [markdown]
# ## 进入mmdetection主目录

# %%
import os

# %%
os.chdir('mmdetection')

# %% [markdown]
# ## 目标检测算法：RTMDet

# %%
# !python tools/train.py data/rtmdet_tiny_ear.py
# Out:
# 06/03 17:15:40 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Mar  8 2023, 14:00:05) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 3778715
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## 在`work_dirs`目录下，查看训练日志和训练得到的模型权重文件

# %% [markdown]
# ## 测试集上评估模型精度

# %%
# !python tools/test.py data/rtmdet_tiny_ear.py \
                      work_dirs/rtmdet_tiny_ear/best_coco_bbox_mAP_epoch_179.pth
# Out:
# 06/04 11:28:49 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Mar  8 2023, 14:00:05) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 644251554
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## 预测

# %%
#图片
# !python demo/image_demo.py \
        data/test_ears/pic.jpg \
        data/rtmdet_tiny_ear.py \
        --weights work_dirs/rtmdet_tiny_ear/best_coco_bbox_mAP_epoch_179.pth \
        --out-dir outputs/E2_rtmdet/img \
        --device cuda:0 \
        --pred-score-thr 0.3
# Out:
# Loads checkpoint by local backend from path: work_dirs/rtmdet_tiny_ear/best_coco_bbox_mAP_epoch_179.pth
# 06/04 11:55:57 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 06/04 11:55:57 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /home/xpg/miniconda3/envs/openmmlab-learning/lib/python3.9/site-packages/torch/f2;76;56;63m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# unctional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will
# be required to pass the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#视频
# !python demo/video_demo.py \
        data/test_ears/video.mp4 \
        data/rtmdet_tiny_ear.py \
        work_dirs/rtmdet_tiny_ear/best_coco_bbox_mAP_epoch_179.pth \
        --device cuda:0 \
        --score-thr 0.6 \
        --out outputs/E2_rtmdet/E2_out_video_rtmdet.mp4
# Out:
# Loads checkpoint by local backend from path: work_dirs/rtmdet_tiny_ear/best_coco_bbox_mAP_epoch_179.pth
# 06/04 11:57:37 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# [ERROR:0@3.722] global cap.cpp:595 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.7.0) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): outputs/E2_rtmdet/video in function 'icvExtractPattern'
#
#
# [                                                  ] 0/236, elapsed: 0s, ETA:/home/xpg/miniconda3/envs/openmmlab-learning/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# # 进入mmpose主目录

# %%
os.chdir('mmpose')

# %% [markdown]
# # 训练RTMPose

# %%
# !python tools/train.py data/rtmpose-s-ear.py
# Out:
# 06/03 18:25:39 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Mar  8 2023, 14:00:05) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 21
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# # 测试集上评估模型精度

# %%
# !python tools/test.py data/rtmpose-s-ear.py \
                      work_dirs/rtmpose-s-ear/best_PCK_epoch_270.pth
# Out:
# 06/04 11:23:16 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Mar  8 2023, 14:00:05) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 21
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## 预测

# %%
# 图片
# !python demo/topdown_demo_with_mmdet.py \
        data/rtmdet_tiny_ear.py \
        checkpoint/best_coco_bbox_mAP_epoch_179.pth \
        data/rtmpose-s-ear.py \
        checkpoint/best_PCK_epoch_270.pth \
        --input data/test_ears/pic.jpg \
        --output-root outputs/G2_RTMDet-RTMPose \
        --device cuda:0 \
        --bbox-thr 0.5 \
        --kpt-thr 0.5 \
        --nms-thr 0.3 \
        --radius 5 \
        --thickness 10 \
        --draw-bbox \
        --draw-heatmap \
        --show-kpt-idx
# Out:
# Loads checkpoint by local backend from path: checkpoint/best_coco_bbox_mAP_epoch_179.pth
# Loads checkpoint by local backend from path: checkpoint/best_PCK_epoch_270.pth
# 06/04 12:18:29 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /home/xpg/miniconda3/envs/openmmlab-learning/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /media/xpg/13ecfb4d-71cb-47b8-bc77-f73b09f64929/xpg/Openmmlab/training_camp_2/MMPose_Tutorials/2023/0524/mmpose/mmpose/models/heads/coord_cls_heads/rtmcc_head.py:217: UserWarning: The predicted simcc values are normalized for visualization. This may cause discrepancy between the keypoint scores and the 1D heatmaps.
# ...

# %%
#视频
# !python demo/topdown_demo_with_mmdet.py \
        data/rtmdet_tiny_ear.py \
        checkpoint/best_coco_bbox_mAP_epoch_179.pth \
        data/rtmpose-s-ear.py \
        checkpoint/best_PCK_epoch_270.pth \
        --input data/test_ears/video.mp4 \
        --output-root outputs/G2_Video \
        --device cuda:0 \
        --bbox-thr 0.5 \
        --kpt-thr 0.5 \
        --nms-thr 0.3 \
        --radius 5 \
        --thickness 10 \
        --draw-bbox \
        --draw-heatmap \
        --show-kpt-idx
# Out:
# Loads checkpoint by local backend from path: checkpoint/best_coco_bbox_mAP_epoch_179.pth
# Loads checkpoint by local backend from path: checkpoint/best_PCK_epoch_270.pth
# 06/04 12:18:36 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /home/xpg/miniconda3/envs/openmmlab-learning/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /media/xpg/13ecfb4d-71cb-47b8-bc77-f73b09f64929/xpg/Openmmlab/training_camp_2/MMPose_Tutorials/2023/0524/mmpose/mmpose/models/heads/coord_cls_heads/rtmcc_head.py:217: UserWarning: The predicted simcc values are normalized for visualization. This may cause discrepancy between the keypoint scores and the 1D heatmaps.
# ...
